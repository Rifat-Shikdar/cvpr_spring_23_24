# %%
evenNoTuple = (2, 4, 6, 8, 10)
print(evenNoTuple)
# Out:
# (2, 4, 6, 8, 10)

# %%
product = 1
for num in evenNoTuple:
    product *= num
# Print the product of all element
print("The product is:", product)
# Out:
# The product is: 3840
