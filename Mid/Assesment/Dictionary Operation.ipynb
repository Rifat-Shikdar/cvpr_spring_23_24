# %%
lowercaseAlphabets = 'abcde'
asciiDict = {char: ord(char) for char in lowercaseAlphabets}
print("Dictionary with lowercase alphabets as keys and their ASCII values as values:")
print(asciiDict)
# Out:
# Dictionary with lowercase alphabets as keys and their ASCII values as values:
# {'a': 97, 'b': 98, 'c': 99, 'd': 100, 'e': 101}
